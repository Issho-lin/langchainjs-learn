// %%
/*
 * @Author: linqibin
 * @Date: 2025-08-25 09:03:18
 * @LastEditors: linqibin
 * @LastEditTime: 2025-08-25 14:11:14
 * @Description: 
 * 
 * Copyright (c) 2025 by 智慧空间研究院/金地空间科技, All Rights Reserved. 
 */
import { MongoClient } from "mongodb";

const uri = "mongodb://linqibin:950918@43.136.112.180:27017/fastgpt?authSource=admin&directConnection=true";

const client = new MongoClient(uri)

await client.connect()

const database = client.db('platform')

const collection = database.collection('project')

// const res = await collection.aggregate([
//     { $group: { _id: '$orgId', avg_area: { $avg: '$houseArea' } } },
//     { $project: { _id: 0, id: '$_id', avg_area: 1 } }
// ]).toArray()

// console.log(res)

// const result = await collection.find({ orgId: { $gt: 30 } }).toArray()

// console.log(result)

// await collection.findOne({ name: '海南旧改' })

await collection.aggregate([
    { $group: { _id: '$orgId', avg_area: { $avg: '$houseArea' } } },
    { $project: { _id: 0, id: '$_id', avg_area: { $round: ['$avg_area', 0] } } },
    { $match: { avg_area: { $gt: 120 } } },
    { $sort: { id: 1 } }
]).toArray()
// Out:
// [
//   { id: 1, avg_area: 130 },
//   { id: 2, avg_area: 129 },
//   { id: 4, avg_area: 210 },
//   { id: 6, avg_area: 168 },
//   { id: 10119, avg_area: 164 },
//   { id: 10128, avg_area: 160 }
// ]
