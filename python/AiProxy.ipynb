# %%
'''
Author: linqibin
Date: 2025-08-20 15:14:38
LastEditors: linqibin
LastEditTime: 2025-08-20 16:31:09
Description: 

Copyright (c) 2025 by 智慧空间研究院/金地空间科技, All Rights Reserved. 
'''
from langchain_openai import ChatOpenAI

model = ChatOpenAI(
    model_name="hunyuan-lite",
    base_url='http://43.136.112.180:3001/v1',
    api_key='aiproxy',
    default_headers={
        "Aiproxy-Channel": "4"
    }
)

for chunk in model.stream("你好, 请介绍一下你自己"):
    print(chunk.content, end="", flush=True)
# Out:
# 你好呀，我是一个充满活力、聪明伶俐的人工智能助手-语灵，用中文与你交流。我热爱各种兴趣爱好，并具备丰富的知识。无论是闲聊倾诉，还是解答各类疑问，我都愿意陪伴你。我很乐意为你提供一些建议和参考意见，但也明白自己的局限性，会不断学习和进步。对你的任何问题，我都会认真对待，希望我的回答能让你满意。

# %%
for chunk in model.stream("人生好难啊"):
    print(chunk.content, end="", flush=True)
# Out:
# “人生好难啊”这句话表达了人们对生活挑战和困难的感受。确实，生活中充满了各种挑战和困难，这些困难可能来自于工作、学习、人际关系、健康等各个方面。面对这些困难，人们可能会感到焦虑、沮丧和无助。
#
# 然而，面对困难并不意味着放弃。相反，正是这些困难塑造了我们的性格和能力，让我们更加坚强和成熟。以下是一些建议，帮助你更好地应对生活中的困难：
#
# 1. **接受现实**：首先，要正视生活中的困难，不要逃避或否认。只有接受现实，才能更好地应对问题。
# 2. **分析原因**：试着找出问题的根源，分析导致困难的原因。这有助于你找到解决问题的方法。
# 3. **制定计划**：根据问题的原因和性质，制定一个实际的计划来解决问题。确定目标、分配任务，并设定时间表。
# 4. **寻求支持**：与家人、朋友或专业人士分享你的困难，寻求他们的建议和支持。他们可能会提供不同的视角和解决方案。
# 5. **保持积极心态**：尽量保持积极的心态，相信自己能够克服困难。积极心态有助于激发内在的动力和潜能。
# 6. **分步解决**：将大问题分解成若干个小问题，然后逐一解决。这样做可以让你更容易取得进展，增强信心。
# 7. **坚持锻炼**：锻炼有助于缓解压力，提高身体素质和心理韧性。定期进行适度的锻炼，有助于你更好地应对困难。
#
# 总之，人生确实充满挑战和困难，但只要我们勇敢面对并采取积极的应对措施，就一定能够克服它们。记住，困难只是暂时的，而成长和进步是永恒的。
