# %%
import pymongo

client = pymongo.MongoClient('mongodb://linqibin:950918@43.136.112.180:27017/fastgpt?authSource=admin&directConnection=true')

database = client.get_database('platform')

collection = database.get_collection('project')

collection.aggregate([
    { '$group': { '_id': '$orgId', 'avg_area': { '$avg': '$houseArea' } } },
    { '$project': { '_id': 0, 'id': '$_id', 'avg_area': { '$round': ['$avg_area', 0] }  } },
    { '$match': { 'avg_area': { '$gt': 120 } } },
]).to_list()

# collection.find_one({ 'name': '海南旧改' })

# collection.find({ 'name': { '$regex': '^海南' } }).to_list()
# Out:
# [{'id': 10119, 'avg_area': 164.0},
#  {'id': 6, 'avg_area': 168.0},
#  {'id': 4, 'avg_area': 210.0},
#  {'id': 1, 'avg_area': 130.0},
#  {'id': 2, 'avg_area': 129.0},
#  {'id': 10128, 'avg_area': 160.0}]
