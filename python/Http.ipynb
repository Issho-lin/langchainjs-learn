# %%
import requests

# rst = requests.get(
#     url='https://ire.bytedance.net/api/mibp-configuration/v1/zuTai/getDeviceProperty?nid=edgex/edgex_2CEC5866A9484116A67/ACATVA/HZ-T1-F22-VAV-28-TROX&projectCode=project04',
#     headers={
#         "cookies": "_bl_uid=1CmU4e96k75rk65ks5sC07jo0z3L; MIBP_SSO_SESSION_ID=28797_a310d10af2a44da6af79e5814d9277ac_B; _tea_utm_cache_1229=undefined; Hm_lvt_b97569d26a525941d8d163729d284198=1755761687; Hm_lpvt_b97569d26a525941d8d163729d284198=1755761687; HMACCOUNT=A5F033C1DCC88D8A; Hm_lvt_e8002ef3d9e0d8274b5b74cc4a027d08=1755761687; Hm_lpvt_e8002ef3d9e0d8274b5b74cc4a027d08=1755761687",
#         "host": "ire.bytedance.net",
#         "project-code": "project04",
#         "project-id": "272430276",
#         "sso-session": "28797_a310d10af2a44da6af79e5814d9277ac_B"
#     }
# )

# print(rst.json())

res = requests.post(
    url="https://ire.bytedance.net/api/apps-device-manager/v1/device/getDeviceByNid",
    headers={
        "cookies": "_bl_uid=1CmU4e96k75rk65ks5sC07jo0z3L; MIBP_SSO_SESSION_ID=28797_a310d10af2a44da6af79e5814d9277ac_B; _tea_utm_cache_1229=undefined; Hm_lvt_b97569d26a525941d8d163729d284198=1755761687; Hm_lpvt_b97569d26a525941d8d163729d284198=1755761687; HMACCOUNT=A5F033C1DCC88D8A; Hm_lvt_e8002ef3d9e0d8274b5b74cc4a027d08=1755761687; Hm_lpvt_e8002ef3d9e0d8274b5b74cc4a027d08=1755761687",
        "host": "ire.bytedance.net",
        "project-code": "project04",
        "project-id": "272430276",
        "sso-session": "28797_a310d10af2a44da6af79e5814d9277ac_B",
        "eagleeye-pappname": "h6t0846fhp@33b9d28baee0684",
        "eagleeye-sessionid": "vzmI0ehdl527dC4Lew62x88sgs8b",
        "eagleeye-traceid": "eb0e45e417557703423101836e0684",
        "content-type": "application/json"
    },
    json={
        "nid": "edgex/edgex_2CEC5866A9484116A67/ACATVA/HZ-T2-F5-VAV-83-TROX",
        "projectCode": "project04"
    }
)

res.json()
# Out:
# {'traceId': '9bec619cccc94131b9c57dcf3022a43a.164.17558241221718233',
#  'success': True,
#  'errorCode': 200,
#  'errorMsg': '',
#  'args': None,
#  'data': {'deviceId': '55489',
#   'deviceName': 'HZ-T2-F5-VAV-83-TROX',
#   'systemCode': 'SupplyAndExhustFan',
#   'deviceTypeCode': 'ACATVA',
#   'deviceTypeName': 'VAVBOX',
#   'iconUrl': None,
#   'status': None,
#   'floorName': 'VAV空间',
#   'point': None,
#   'latestReportTime': '2025-08-22T08:55:16.586',
#   'nid': 'edgex/edgex_2CEC5866A9484116A67/ACATVA/HZ-T2-F5-VAV-83-TROX',
#   'moid': '6895ad7b67a91777f5c563b5',
#   'props': [{'dataIndex': 'cooling_heating_switch',
#     'title': '送风温度',
#     'value': '23.32',
#     'unit': ' °C',
#     'dataType': 'data',
#     'source': 'shadow',
#     'isAlarm': None},
#    {'dataIndex': 'damper_opening_setting',
#     'title': '风阀开度设定',
#     'value': '100',
#     'unit': ' %',
#     'dataType': 'data',
#     'source': 'shadow',
#     'isAlarm': None},
# ...
