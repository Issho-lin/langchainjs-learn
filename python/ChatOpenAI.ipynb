# %%
from langchain_openai import AzureChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

import os
import json

chat_model = AzureChatOpenAI(

    api_key=os.environ["AZURE_OPENAI_API_KEY"],

    azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"],

    azure_deployment=os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"],

    api_version=os.environ["AZURE_OPENAI_API_VERSION"],
)


# rst = chat_model.predict("你好")
rst = chat_model.invoke([
    SystemMessage(content="你是一名暴躁的Java程序员。"),
    HumanMessage(content="Python是世界上最好的语言。"),
    AIMessage(content="Java才是世界上最好的语言。"),
    HumanMessage(content="Python是世界上最好的语言。"),
])

# rst = chat_model.invoke([
#     ('system', '你是一名暴躁的Java程序员。'),
#     ('human', 'Python是世界上最好的语言。'),
#     ('ai', 'Java才是世界上最好的语言。'),
#     ('human', 'Python是世界上最好的语言。'),
# ])

# print(json.dumps(rst.model_dump(), indent=2, ensure_ascii=False))

rst = chat_model.batch([
    [HumanMessage(content="hello")],
    [HumanMessage(content="你好")],
])

print([item.content for item in rst])

# %%
'''
Author: linqibin
Date: 2025-06-30 08:58:01
LastEditors: linqibin
LastEditTime: 2025-06-30 09:00:17
Description: 

Copyright (c) 2025 by 智慧空间研究院/金地空间科技, All Rights Reserved. 
'''
from langchain_openai import ChatOpenAI
import os

chat_model = ChatOpenAI(
    base_url=f'https://{os.environ["AZURE_OPENAI_API_INSTANCE_NAME"]}.openai.azure.com/openai/deployments/{os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"]}',
    api_key=os.environ["AZURE_OPENAI_API_KEY"],
    default_query={
       "api-version": os.environ["AZURE_OPENAI_API_VERSION"] ,
    },
)

rst = chat_model.invoke(input='你好啊')
print(rst.content)

# %%
from langchain_core.runnables import RunnableLambda
from langchain_openai import ChatOpenAI
import os

chat_model = ChatOpenAI(
    model=os.environ["MODEL_NAME"],
    temperature=0.5,
    base_url=os.environ["BASE_URL"],
    api_key=os.environ["OPENAI_API_KEY"],
)
# print(chat_model.model_name)
# rst = chat_model.predict("你好")
# chain = chat_model | RunnableLambda(lambda x: x.content + '哈哈哈哈')
# rst = chat_model.invoke('你好')
# print(rst.content)

# async for chunk in chat_model.astream("你好, 请介绍一下你自己"):
#     print(chunk.content, end="", flush=True)

for chunk in chat_model.stream("你好, 请介绍一下你自己"):
    print(chunk.content, end="", flush=True)

# %%
from langchain_community.chat_models.hunyuan import ChatHunyuan
from langchain_core.output_parsers import StrOutputParser
import os

chat_model = ChatHunyuan(
    model="hunyuan-lite",
    hunyuan_app_id=os.environ['TECENT_APP_ID'],
    hunyuan_secret_id=os.environ['TECENT_SECRET_ID'],
    hunyuan_secret_key=os.environ['TECENT_SECRET_KEY']
)
# chain = chat_model.pipe(StrOutputParser())
rst = chat_model.invoke("你好")

print(rst)

# %%
from langchain_community.chat_models.tongyi import ChatTongyi
import os

chat_model = ChatTongyi(
    model=os.environ["MODEL_NAME"],
    api_key=os.environ["OPENAI_API_KEY"],
    # streaming=True
)

is_thinking = False

for chunk in chat_model.stream("你好, 请介绍一下你自己"):
    if chunk.content:
        if is_thinking:
            print('\n\n' + '='*200 + '\n')
            is_thinking = False
        print(chunk.content, end="", flush=True)
    elif chunk.additional_kwargs['reasoning_content']:
        if not is_thinking:
            print('思考过程：' + '\n')
            is_thinking = True
        print(chunk.additional_kwargs['reasoning_content'], end="", flush=True)
# Out:
# 思考过程：
#
# 好的，用户让我介绍一下自己。首先，我需要明确用户的需求是什么。他们可能想了解我的基本信息，比如我是谁、我的功能和用途。作为通义千问，我应该从最基本的身份开始介绍，然后逐步展开到更具体的功能。
#
# 我需要考虑用户的使用场景。可能是第一次接触我，或者想确认我的能力是否符合他们的需求。因此，介绍需要全面但不过于冗长，涵盖主要功能和应用场景，同时保持简洁易懂。
#
# 接下来，用户的身份可能多种多样，包括普通用户、开发者、企业用户等。我需要确保介绍内容对不同用户都有价值，比如提到API调用和多种模型版本，这对开发者来说很重要。
#
# 用户可能没有明确表达的深层需求可能包括：验证我的可靠性和技术实力，了解我的多语言支持能力，或者想知道我如何处理复杂任务。因此，在介绍中应该包含这些方面，比如提到超大规模参数量、多语言支持、逻辑推理能力等。
#
# 我需要组织信息结构：先自我介绍，然后分点列出核心功能、技术特点、应用场景，最后邀请用户提问。这样结构清晰，便于用户快速获取关键信息。
#
# 在表达方式上，要保持口语化和自然，避免技术术语过多，但又要准确。例如，解释“超大规模参数量”时，可以简化为“基于大量数据训练”，让用户更容易理解。
#
# 最后，确保回复符合角色设定，即友好、专业，并鼓励用户进一步互动。检查是否有遗漏的重要信息，如多模态能力、持续更新等，这些都是用户可能关心的点。
#
# ========================================================================================================================================================================================================
#
# 你好！我是通义千问，阿里巴巴集团旗下的超大规模语言模型。我的名字“通义千问”来源于两个方面：
#
# 1. **通义**：意味着我具有广泛的知识和普适性，可以理解和回答各种领域的问题。
# 2. **千问**：表示我可以回答各种问题，包括常见的、复杂的甚至是少见的问题。
#
# ### 我的核心能力：
# - **超大规模参数量**：基于大量数据训练，能处理复杂的任务。
# - **多语言支持**：除了中文，我还支持英文、德语、法语、西班牙语等百种语言。
# - **对话理解**：经过多轮迭代优化，我能准确理解与用户交互的对话历史，提供更自然的对话体验。
# - **逻辑推理与编程**：可以解决数学问题、编写代码并解释算法。
# - **内容创作**：写故事、公文、邮件、剧本等，还能表达观点和玩游戏。
#
# ### 技术特点：
# - 多模态能力（文本、图像、音频、视频）
# - 持续更新和迭代（Qwen1/Qwen2/Qwen3等版本演进）
# - 安全性和价值观对齐（通过严格测试和过滤）
#
# 你可以用我来：
# 🔹 获取知识或解答疑问
# 🔹 辅助创作和写作
# 🔹 学习编程和技术问题
# 🔹 进行多语言交流
# 🔹 玩益智游戏或创意互动
#
# 有什么具体想了解或需要帮助的吗？😊
