# %%
from langchain_openai import AzureChatOpenAI
import os

chat_model = AzureChatOpenAI(
    api_key=os.environ["AZURE_OPENAI_API_KEY"],
    azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"],
    azure_deployment=os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"],
    api_version=os.environ["AZURE_OPENAI_API_VERSION"],
)

rst = chat_model.predict("你好")
print(rst)
# Out:
# 你好！有什么我可以帮助你的呢？😊

# %%
from langchain_openai import ChatOpenAI

chat_model = ChatOpenAI(
    base_url=f'https://{os.environ["AZURE_OPENAI_API_INSTANCE_NAME"]}.openai.azure.com/openai/deployments/{os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"]}',
    api_key=os.environ["AZURE_OPENAI_API_KEY"],
    default_query={
       "api-version": os.environ["AZURE_OPENAI_API_VERSION"] ,
    },
)

rst = chat_model.invoke(input='你好')
print(rst.content)
# Out:
# 你好！有什么可以帮助你的吗？😊

# %%
from langchain_core.runnables import RunnableLambda
from langchain_openai import ChatOpenAI

chat_model = ChatOpenAI(
    model=os.environ["MODEL_NAME"],
    temperature=0.5,
    base_url=os.environ["BASE_URL"],
    api_key=os.environ["OPENAI_API_KEY"],
)
print(chat_model)
# rst = chat_model.predict("你好")
chain = chat_model | RunnableLambda(lambda x: x.content + '哈哈哈哈')
rst = chain.invoke('你好')
print(rst)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x0000011D32B1F080> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000011D32B6C2C0> root_client=<openai.OpenAI object at 0x0000011D288CBC80> root_async_client=<openai.AsyncOpenAI object at 0x0000011D32B4DA60> model_name='doubao-pro-256k-241115' temperature=0.5 model_kwargs={} openai_api_key=SecretStr('**********') openai_api_base='https://ark.cn-beijing.volces.com/api/v3'
# 你好呀！很高兴能和你聊天呢，有什么好玩的事儿或者疑问都可以和我说说哦。哈哈哈哈

# %%
from langchain_community.chat_models.hunyuan import ChatHunyuan
from langchain_core.output_parsers import StrOutputParser
import os

chat_model = ChatHunyuan(
    model="hunyuan-lite",
    hunyuan_app_id=os.environ['TECENT_APP_ID'],
    hunyuan_secret_id=os.environ['TECENT_SECRET_ID'],
    hunyuan_secret_key=os.environ['TECENT_SECRET_KEY']
)
chain = chat_model.pipe(StrOutputParser())
rst = chain.invoke("你好")
print(rst)
# Out:
# 您好！非常高兴与您交流，今天有什么有趣的事情想和我分享呢😄
