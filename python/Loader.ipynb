# %%
from langchain.document_loaders import JSONLoader
# from pathlib import Path
from pprint import pprint
import json

file_path='../documents/data.json'
# data = json.loads(Path(file_path).read_text())

# pprint(data)

json_loader = JSONLoader(
  file_path=file_path,
  jq_schema='.[].title',
  text_content=False
)

rst = json_loader.load()

pprint(object=rst)
# Out:
# [Document(metadata={'source': '/Users/qibin/Documents/code/langchainjs-learn/documents/data.json', 'seq_num': 1}, page_content='肖申克的救赎'),
#  Document(metadata={'source': '/Users/qibin/Documents/code/langchainjs-learn/documents/data.json', 'seq_num': 2}, page_content='霸王别姬'),
#  Document(metadata={'source': '/Users/qibin/Documents/code/langchainjs-learn/documents/data.json', 'seq_num': 3}, page_content='泰坦尼克号'),
#  Document(metadata={'source': '/Users/qibin/Documents/code/langchainjs-learn/documents/data.json', 'seq_num': 4}, page_content='阿甘正传'),
#  Document(metadata={'source': '/Users/qibin/Documents/code/langchainjs-learn/documents/data.json', 'seq_num': 5}, page_content='千与千寻'),
#  Document(metadata={'source': '/Users/qibin/Documents/code/langchainjs-learn/documents/data.json', 'seq_num': 6}, page_content='美丽人生'),
#  Document(metadata={'source': '/Users/qibin/Documents/code/langchainjs-learn/documents/data.json', 'seq_num': 7}, page_content='这个杀手不太冷')]
